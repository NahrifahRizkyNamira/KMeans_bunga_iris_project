# %% [markdown]
# <a href="https://colab.research.google.com/github/NahrifahRizkyNamira/KMeans_bunga_iris_project/blob/main/kmeans_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import library
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

# Load dataset Iris
iris = load_iris()
data = iris.data

# Proses K-Means
kmeans = KMeans(n_clusters=3,
random_state=42)
kmeans.fit(data)

# Ambil hasil cluster
labels = kmeans.labels_

# Visualisasi hasil
plt.scatter(data[:, 0], data[:,1], c=labels)
plt.xlabel("Panjang Sepal")
plt.ylabel("Lebar Sepal")
plt.title("Pengelompokan Data Bunga Iris Menggunakan Metode K-Means")
plt.show()
